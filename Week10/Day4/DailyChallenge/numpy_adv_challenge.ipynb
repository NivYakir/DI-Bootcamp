# %%
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization
sns.set_style('whitegrid') # set style for visualization
import warnings # ignore warnings
warnings.filterwarnings('ignore')
import requests, zipfile, io
from sklearn.impute import KNNImputer

# %% [markdown]
# # Loading Dataset

# %%
# Download and Unzip the Dataset
url = "https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%206%20-%20Applications%20for%20Data%20Analysis/W6D2%20-%20Advanced%20Numpy/globalpowerplantdatabasev130.zip"

r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("data")

# %%
# Load data as Dataframe
df = pd.read_csv(r'C:\Repositories\DI-Bootcamp\Week10\Day4\DailyChallenge\data\global_power_plant_database.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  object
#  1   country_long                    34936 non-null  object
#  2   name                            34936 non-null  object
#  3   gppd_idnr                       34936 non-null  object
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  object
#  8   other_fuel1                     1944 non-null   object
#  9   other_fuel2                     276 non-null    object
#  10  other_fuel3                     92 non-null     object
#  11  commissioning_year              17447 non-null  float64
# ...

# %%
# Drop Unecessary Columns
df = df.drop(columns=['other_fuel1', 'other_fuel2', 'other_fuel3', 'owner', 'source', 'url', 'wepp_id', 'geolocation_source'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  object
#  1   country_long                    34936 non-null  object
#  2   name                            34936 non-null  object
#  3   gppd_idnr                       34936 non-null  object
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  object
#  8   commissioning_year              17447 non-null  float64
#  9   year_of_capacity_data           14887 non-null  float64
#  10  generation_gwh_2013             6417 non-null   float64
#  11  generation_gwh_2014             7226 non-null   float64
# ...

# %%
# Separate Numeric vs Categorical
df_numeric = df.select_dtypes(include=('number'))
df_caterogical = df.select_dtypes(exclude=('number'))

for col in df_caterogical:
    print(df_caterogical[col].value_counts())
# Out:
# country
# USA    9833
# CHN    4235
# GBR    2751
# BRA    2360
# FRA    2155
#        ...
# GNB       1
# LCA       1
# PSE       1
# SUR       1
# ESH       1
# Name: count, Length: 167, dtype: int64
# country_long
# United States of America    9833
# China                       4235
# United Kingdom              2751
# Brazil                      2360
# France                      2155
#                             ...
# Guinea-Bissau                  1
# Saint Lucia                    1
# Palestine                      1
# Suriname                       1
# Western Sahara                 1
# Name: count, Length: 167, dtype: int64
# name
# Santo Antônio                                            6
# Santa Rosa                                               5
# Funil                                                    5
# Santa Helena                                             5
# São José                                                 5
# ...

# %%
df.describe()
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  \
# count  34936.000000  34936.000000  34936.000000        17447.000000
# mean     163.355148     32.816637     -6.972803         1997.414823
# std      489.636072     22.638603     78.405850           23.397835
# min        1.000000    -77.847000   -179.977700         1896.000000
# 25%        4.900000     29.256475    -77.641550         1988.000000
# 50%       16.745000     39.727750     -2.127100         2007.000000
# 75%       75.344250     46.263125     49.502675         2014.000000
# max    22500.000000     71.292000    179.388700         2020.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count           14887.000000          6417.000000          7226.000000
# mean             2018.218849           592.696107           656.863891
# std                 1.606428          2174.833482          2231.464288
# ...

# %% [markdown]
# # Cleaning
